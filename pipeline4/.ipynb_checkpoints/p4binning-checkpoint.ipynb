# %%
#Importing the packages that we need 
import pandas as pd
import numpy as np

# %%
#Loading in the csv file
df = pd.read_csv('../csv_files/p4final.csv', header=0, index_col=0)
df.head()
# Out:
#      I1                                  I2    I3  pIPO    pH    pL  \
# 0  AATI  ADVANCED ANALOGIC TECHNOLOGIES INC  3674  10.0   9.5   8.5
# 1  ABPI     ACCENTIA BIOPHARMACEUTICALS INC  2834   8.0  10.0   8.0
# 2  ACAD          ACADIA PHARMACEUTICALS INC  2834   7.0  14.0  12.0
# 3  ACHN       ACHILLION PHARMACEUTICALS INC  2834  11.5  16.0  14.0
# 4  ACLI     AMERICAN COMMERCIAL LINES INC.   4492  21.0  21.0  19.0
#
#        p1day  Pmid  Y1  Y2 ...        C5p       C6p       T4p       T3p  \
# 0  11.870000   9.0   0   1 ...   0.054797  1.282356  0.168664  0.174370
# 1   7.250000   9.0   1   0 ...   2.432764 -0.759933  0.229323  0.099791
# 2   6.700000  13.0   1   0 ...  -0.232390 -0.759933  0.118072  0.177832
# 3  12.390000  15.0   1   1 ...  -0.276002 -0.759933 -1.244015  0.233984
# 4  56.599998  20.0   0   1 ...  -0.021399  1.027869 -0.574359  0.023742
#
#         T5p       S1p       S2p       S3p   C2  C3p
# 0  0.310576 -0.147291  0.165044 -0.128181  1.0    0
# 1 -0.016410 -1.241195  0.781034 -0.147795  0.0    1
# 2  1.107408  2.766871 -0.974778  0.044531  1.0    1
# 3  1.093939  2.091573 -0.603481  0.697712  1.0    1
# 4 -0.357698 -0.365024  0.448793 -0.006539  1.0    0
#
# [5 rows x 23 columns]

# %%
#To fill the '-' values in 'I3' with 0
df['I3'].replace(to_replace='-', value=0, inplace=True)
df.head(10)
# Out:
#      I1                                  I2    I3  pIPO    pH    pL  \
# 0  AATI  ADVANCED ANALOGIC TECHNOLOGIES INC  3674  10.0   9.5   8.5
# 1  ABPI     ACCENTIA BIOPHARMACEUTICALS INC  2834   8.0  10.0   8.0
# 2  ACAD          ACADIA PHARMACEUTICALS INC  2834   7.0  14.0  12.0
# 3  ACHN       ACHILLION PHARMACEUTICALS INC  2834  11.5  16.0  14.0
# 4  ACLI     AMERICAN COMMERCIAL LINES INC.   4492  21.0  21.0  19.0
# 5  ACOM                  Ancestry.com Inc.   7379  13.5  14.5  12.5
# 6  ACOR             ACORDA THERAPEUTICS INC  2836   6.0  13.0  11.0
# 7  ACRX          ACELRX PHARMACEUTICALS INC  2834   5.0  14.0  12.0
# 8  ACTV                  ACTIVE NETWORK INC  7372  15.0  18.0  16.0
# 9   ACW                       ACCURIDE CORP  3714   9.0  19.0  17.0
#
#        p1day  Pmid  Y1  Y2 ...        C5p       C6p       T4p       T3p  \
# 0  11.870000   9.0   0   1 ...   0.054797  1.282356  0.168664  0.174370
# 1   7.250000   9.0   1   0 ...   2.432764 -0.759933  0.229323  0.099791
# 2   6.700000  13.0   1   0 ...  -0.232390 -0.759933  0.118072  0.177832
# 3  12.390000  15.0   1   1 ...  -0.276002 -0.759933 -1.244015  0.233984
# 4  56.599998  20.0   0   1 ...  -0.021399  1.027869 -0.574359  0.023742
# 5  14.200000  13.5   0   1 ...   0.877692 -0.759933  0.206671 -0.877693
# 6   6.720000  12.0   1   1 ...  -0.174786 -0.759933  1.923885  0.001249
# 7   4.550000  13.0   1   0 ...  -0.924058 -0.759933  2.774518  0.078014
# 8  15.900000  17.0   1   1 ...   0.516091 -0.759933 -1.234366  0.174277
# 9   0.000000  18.0   1   0 ...  -0.436258 -0.759933 -1.599295  0.016985
#
#         T5p       S1p       S2p       S3p   C2  C3p
# 0  0.310576 -0.147291  0.165044 -0.128181  1.0    0
# 1 -0.016410 -1.241195  0.781034 -0.147795  0.0    1
# 2  1.107408  2.766871 -0.974778  0.044531  1.0    1
# 3  1.093939  2.091573 -0.603481  0.697712  1.0    1
# 4 -0.357698 -0.365024  0.448793 -0.006539  1.0    0
# 5 -0.771227 -1.098622 -1.414595 -0.459615  1.0    0
# 6 -0.900713  0.044352 -0.776948 -1.072698  1.0    1
# 7 -7.096903 -0.132588  0.653150 -0.150733  0.0    1
# 8  1.121620 -0.760343 -0.129186  1.455285  1.0    1
# 9 -0.151621  1.774249  0.385389  1.540556  1.0    0
#
# [10 rows x 23 columns]

# %%
#Filling in ID #s that had originally had multiple values 
##Found the correct ID #s on the internet
df.iloc[118, df.columns.get_loc('I3')] = 5261
df.iloc[174, df.columns.get_loc('I3')] = 7812
df.iloc[181, df.columns.get_loc('I3')] = 191
df.iloc[187, df.columns.get_loc('I3')] = 5731
df.iloc[221, df.columns.get_loc('I3')] = 7389
df.iloc[246, df.columns.get_loc('I3')] = 7372
df.iloc[499, df.columns.get_loc('I3')] = 3663
df.iloc[620, df.columns.get_loc('I3')] = 5065

# %%
#Going to bin column 'I3'. Based on the Major Industries and then all 'others'

def assign_industry_bins(I3):
    if int(I3) >= 2000 and int(I3) <= 3999:  #Returning '1' if is in Manufacturing industry
        return(1)
    if int(I3) >= 7000 and int(I3) <= 8999:  #Returing '2' if is in Services industy
        return(2)
    else:                          #Returning '3' for all industries other than
        return(3)                  ##Manufacturing and Services

#Creating a Industry Bins column in the DataFrame
df['Industry_Bins'] = df['I3'].apply(assign_industry_bins)

# %%
df.head()
# Out:
#      I1                                  I2    I3  pIPO    pH    pL  \
# 0  AATI  ADVANCED ANALOGIC TECHNOLOGIES INC  3674  10.0   9.5   8.5
# 1  ABPI     ACCENTIA BIOPHARMACEUTICALS INC  2834   8.0  10.0   8.0
# 2  ACAD          ACADIA PHARMACEUTICALS INC  2834   7.0  14.0  12.0
# 3  ACHN       ACHILLION PHARMACEUTICALS INC  2834  11.5  16.0  14.0
# 4  ACLI     AMERICAN COMMERCIAL LINES INC.   4492  21.0  21.0  19.0
#
#        p1day  Pmid  Y1  Y2      ...             C6p       T4p       T3p  \
# 0  11.870000   9.0   0   1      ...        1.282356  0.168664  0.174370
# 1   7.250000   9.0   1   0      ...       -0.759933  0.229323  0.099791
# 2   6.700000  13.0   1   0      ...       -0.759933  0.118072  0.177832
# 3  12.390000  15.0   1   1      ...       -0.759933 -1.244015  0.233984
# 4  56.599998  20.0   0   1      ...        1.027869 -0.574359  0.023742
#
#         T5p       S1p       S2p       S3p   C2  C3p  Industry_Bins
# 0  0.310576 -0.147291  0.165044 -0.128181  1.0    0              1
# 1 -0.016410 -1.241195  0.781034 -0.147795  0.0    1              1
# 2  1.107408  2.766871 -0.974778  0.044531  1.0    1              1
# 3  1.093939  2.091573 -0.603481  0.697712  1.0    1              1
# 4 -0.357698 -0.365024  0.448793 -0.006539  1.0    0              3
#
# [5 rows x 24 columns]

# %%
df.to_csv('../csv_files/p4binning.csv')

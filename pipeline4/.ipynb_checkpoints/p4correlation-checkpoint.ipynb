# %% [markdown]
# **Import Data**

# %%
# import appropriate packages
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# read the excel file
# had to install the xlrd package to read the file 
df = pd.read_csv("../csv_files/p4final.csv", index_col=0)
df.head()
# Out:
#      I1                                  I2    I3  pIPO    pH    pL  \
# 0  AATI  ADVANCED ANALOGIC TECHNOLOGIES INC  3674  10.0   9.5   8.5
# 1  ABPI     ACCENTIA BIOPHARMACEUTICALS INC  2834   8.0  10.0   8.0
# 2  ACAD          ACADIA PHARMACEUTICALS INC  2834   7.0  14.0  12.0
# 3  ACHN       ACHILLION PHARMACEUTICALS INC  2834  11.5  16.0  14.0
# 4  ACLI     AMERICAN COMMERCIAL LINES INC.   4492  21.0  21.0  19.0
#
#        p1day  Pmid  Y1  Y2 ...        C5p       C6p       T4p       T3p  \
# 0  11.870000   9.0   0   1 ...   0.054797  1.282356  0.168664  0.174370
# 1   7.250000   9.0   1   0 ...   2.432764 -0.759933  0.229323  0.099791
# 2   6.700000  13.0   1   0 ...  -0.232390 -0.759933  0.118072  0.177832
# 3  12.390000  15.0   1   1 ...  -0.276002 -0.759933 -1.244015  0.233984
# 4  56.599998  20.0   0   1 ...  -0.021399  1.027869 -0.574359  0.023742
#
#         T5p       S1p       S2p       S3p   C2  C3p
# 0  0.310576 -0.147291  0.165044 -0.128181  1.0    0
# 1 -0.016410 -1.241195  0.781034 -0.147795  0.0    1
# 2  1.107408  2.766871 -0.974778  0.044531  1.0    1
# 3  1.093939  2.091573 -0.603481  0.697712  1.0    1
# 4 -0.357698 -0.365024  0.448793 -0.006539  1.0    0
#
# [5 rows x 23 columns]

# %%
# filter out Y1 and Y2 (our targets)
df = df.drop(['I1','I2','I3','pIPO','pH','pL','p1day','Pmid'],axis=1)
df.head()
# Out:
#    Y1  Y2        C1        C4        C7       C5p       C6p       T4p  \
# 0   0   1  0.013297  0.671107 -0.561408  0.054797  1.282356  0.168664
# 1   1   0  1.259277 -0.641901 -0.861441  2.432764 -0.759933  0.229323
# 2   1   0 -0.447500  0.412402 -1.331894 -0.232390 -0.759933  0.118072
# 3   1   1  0.888201  0.390990 -1.282655 -0.276002 -0.759933 -1.244015
# 4   0   1 -0.619728 -1.308620  0.887747 -0.021399  1.027869 -0.574359
#
#         T3p       T5p       S1p       S2p       S3p   C2  C3p
# 0  0.174370  0.310576 -0.147291  0.165044 -0.128181  1.0    0
# 1  0.099791 -0.016410 -1.241195  0.781034 -0.147795  0.0    1
# 2  0.177832  1.107408  2.766871 -0.974778  0.044531  1.0    1
# 3  0.233984  1.093939  2.091573 -0.603481  0.697712  1.0    1
# 4  0.023742 -0.357698 -0.365024  0.448793 -0.006539  1.0    0

# %% [markdown]
# **Correlation**

# %%
#Want to see the correlation of every variable using the Spearman method 
df.corr(method='spearman')
# Out:
#            Y1        Y2        C1        C4        C7       C5p       C6p  \
# Y1   1.000000 -0.245474  0.052235 -0.070293 -0.019174 -0.059872 -0.743601
# Y2  -0.245474  1.000000 -0.048579  0.100964 -0.066302  0.065109  0.281459
# C1   0.052235 -0.048579  1.000000  0.090484  0.052531  0.022490 -0.068498
# C4  -0.070293  0.100964  0.090484  1.000000  0.018467 -0.045901  0.093753
# C7  -0.019174 -0.066302  0.052531  0.018467  1.000000 -0.033751 -0.059278
# C5p -0.059872  0.065109  0.022490 -0.045901 -0.033751  1.000000  0.119831
# C6p -0.743601  0.281459 -0.068498  0.093753 -0.059278  0.119831  1.000000
# T4p  0.074500 -0.015126  0.051223  0.082424  0.104258  0.110551 -0.023486
# T3p  0.113340 -0.006453 -0.057398  0.051697 -0.130648  0.104261 -0.028338
# T5p  0.127088  0.028143  0.034253  0.052702 -0.132281  0.126246 -0.083779
# S1p  0.097796 -0.050700  0.030792 -0.000666  0.079030 -0.003917 -0.075907
# S2p  0.166338 -0.098257  0.048102  0.000168  0.180361 -0.058253 -0.116302
# S3p  0.059850  0.049745 -0.026391  0.035323 -0.083691  0.070217 -0.032372
# C2  -0.071471  0.044402  0.007108 -0.031654  0.179541  0.144983  0.112178
# C3p  0.114894  0.033920 -0.036796  0.013009 -0.279146  0.013883 -0.103095
#
#           T4p       T3p       T5p       S1p       S2p       S3p        C2  \
# Y1   0.074500  0.113340  0.127088  0.097796  0.166338  0.059850 -0.071471
# Y2  -0.015126 -0.006453  0.028143 -0.050700 -0.098257  0.049745  0.044402
# C1   0.051223 -0.057398  0.034253  0.030792  0.048102 -0.026391  0.007108
# C4   0.082424  0.051697  0.052702 -0.000666  0.000168  0.035323 -0.031654
# C7   0.104258 -0.130648 -0.132281  0.079030  0.180361 -0.083691  0.179541
# C5p  0.110551  0.104261  0.126246 -0.003917 -0.058253  0.070217  0.144983
# C6p -0.023486 -0.028338 -0.083779 -0.075907 -0.116302 -0.032372  0.112178
# T4p  1.000000 -0.130488 -0.113770  0.054899 -0.042558 -0.105324  0.049210
# T3p -0.130488  1.000000  0.455366  0.181433  0.074961  0.370719  0.013119
# T5p -0.113770  0.455366  1.000000  0.175973  0.154618  0.407189  0.122781
# S1p  0.054899  0.181433  0.175973  1.000000  0.131430  0.201442  0.064651
# S2p -0.042558  0.074961  0.154618  0.131430  1.000000  0.137622  0.026466
# S3p -0.105324  0.370719  0.407189  0.201442  0.137622  1.000000  0.015778
# C2   0.049210  0.013119  0.122781  0.064651  0.026466  0.015778  1.000000
# C3p -0.053753  0.135720  0.233518 -0.061258  0.054732  0.113436 -0.007789
#
#           C3p
# Y1   0.114894
# Y2   0.033920
# C1  -0.036796
# C4   0.013009
# C7  -0.279146
# C5p  0.013883
# C6p -0.103095
# T4p -0.053753
# T3p  0.135720
# T5p  0.233518
# S1p -0.061258
# S2p  0.054732
# S3p  0.113436
# C2  -0.007789
# C3p  1.000000

# %%
#Testing to see which variables are highly correlated to our target variables (Y1 & Y2)
##Highly correlated being > 0.5
Target_1 = df.corr(method='spearman')['Y1'] > 0.5
Target_1
# Out:
# Y1      True
# Y2     False
# C1     False
# C4     False
# C7     False
# C5p    False
# C6p    False
# T4p    False
# T3p    False
# T5p    False
# S1p    False
# S2p    False
# S3p    False
# C2     False
# C3p    False
# Name: Y1, dtype: bool

# %%
#Testing to see which variables are highly correlated to our target variables (Y1 & Y2)
##Highly correlated being > 0.5
Target_2 = df.corr(method='spearman')['Y2'] > 0.5
Target_2
# Out:
# Y1     False
# Y2      True
# C1     False
# C4     False
# C7     False
# C5p    False
# C6p    False
# T4p    False
# T3p    False
# T5p    False
# S1p    False
# S2p    False
# S3p    False
# C2     False
# C3p    False
# Name: Y2, dtype: bool

# %% [markdown]
# **Correlation Heatmap**

# %%
#Created a figure and are able to adjust the size of the graph
plt.figure(figsize = (20,20))
#Created a heatmap using Seaborn to display the correlation based on 'Spearman' method
##Added the annotation so that the numbers appear in each box
display = sns.heatmap(df.corr(method = 'spearman'), annot=True, fmt='.2f', cmap='BuPu', linewidth=.75, cbar_kws={'shrink': .75})
#Created a title
plt.title('Correlation Heatmap')
# Out:
# Text(0.5, 1.0, 'Correlation Heatmap')

# %%
df.to_csv('../csv_files/p4correlation.csv')

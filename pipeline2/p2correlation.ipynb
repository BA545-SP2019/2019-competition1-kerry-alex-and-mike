# 0    0
# 1    1
# 2    1
# 3    1
# 4    0
# 5    0
# 6    1
# 7    1
# 8    1
# 9    0
#
# [10 rows x 23 columns]

# %%
# read in y variables csv 
dfy = pd.read_csv('../csv_files/y.csv', index_col=0)
dfy.head()
# Out:
#    pIPO    pH    pL      p1day  Pmid  Y1  Y2        C6p
# 0  10.0   9.5   8.5  11.870000   9.0   0   1  11.111111
# 1   8.0  10.0   8.0   7.250000   9.0   1   0   0.000000
# 2   7.0  14.0  12.0   6.700000  13.0   1   0   0.000000
# 3  11.5  16.0  14.0  12.390000  15.0   1   1   0.000000
# 4  21.0  21.0  19.0  56.599998  20.0   0   1   5.000000

# %%
# filter our target variables Y1 nad Y2 
dfy = dfy.filter(['Y1', 'Y2'])
dfy.head()
# Out:
#    Y1  Y2
# 0   0   1
# 1   1   0
# 2   1   0
# 3   1   1
# 4   0   1

# %%
# concat df with dfy 
df = pd.concat([df, dfy], axis=1)
df.head()
# Out:
#          C1        C3        C4        C5        C6        C7        T1  \
# 0  0.030756  0.712586  0.669243  0.349506  0.343380 -0.477847  0.131093
# 1  1.279824  0.178082 -0.643726 -0.089084 -1.645602 -0.789310  1.873545
# 2 -0.431183  0.018615  0.410546 -0.764364 -0.662792 -1.277684 -1.897061
# 3  0.907828 -0.143574  0.389135 -0.922547 -0.803873 -1.226569 -0.833698
# 4 -0.603838 -0.733255 -1.310426 -0.010303  0.007764  1.026514  0.735870
#
#          T2        T3        T4 ...  LongSentences  RealWords  LongWords  \
# 0  0.103796  0.147542  0.165663 ...       0.168742   0.385070   0.310826
# 1  1.676347  1.703068  1.745347 ...       0.229402   0.151494  -0.016168
# 2 -1.712308 -1.691699 -1.656026 ...       0.118150   0.395935   1.107680
# 3 -0.884595 -0.835244 -1.055272 ...      -1.243939   0.572453   1.094210
# 4  0.509990  0.496230  0.461735 ...      -0.574282  -0.085718  -0.357465
#
#    PositiveWords  NegativeWords  UncertainWords   C2  C3p  Y1  Y2
# 0      -0.146970       0.165628       -0.128062  1.0    0   0   1
# 1      -1.240880       0.781633       -0.147676  0.0    1   1   0
# 2       2.767209      -0.974221        0.044649  1.0    1   1   0
# 3       2.091907      -0.602916        0.697829  1.0    1   1   1
# 4      -0.364704       0.449384       -0.006421  1.0    0   0   1
#
# [5 rows x 25 columns]

# %% [markdown]
# **Correlation**

# %%
#Want to see the correlation of every variable using the Spearman method 
df.corr(method='spearman')
# Out:
#                       C1        C3        C4        C5        C6        C7  \
# C1              1.000000  0.037293  0.091368  0.050252  0.002052  0.069191
# C3              0.037293  1.000000  0.010623 -0.115628 -0.122202 -0.043115
# C4              0.091368  0.010623  1.000000 -0.017844  0.010170  0.013566
# C5              0.050252 -0.115628 -0.017844  1.000000  0.759087  0.456547
# C6              0.002052 -0.122202  0.010170  0.759087  1.000000  0.533063
# C7              0.069191 -0.043115  0.013566  0.456547  0.533063  1.000000
# T1              0.140925 -0.165602  0.001410  0.494107  0.451795  0.360849
# T2              0.140647 -0.169401  0.015173  0.507526  0.445150  0.340456
# Y1                   0.165504        0.059701 -0.071471  0.114894  1.000000
# Y2                  -0.097063        0.049952  0.044402  0.033920 -0.245474
#
#                       Y2
# C1             -0.009851
# C3             -0.012247
# C4              0.097813
# C5              0.032065
# C6             -0.008882
# C7             -0.031607
# T1             -0.019916
# T2             -0.004766
# T3             -0.021690
# T4             -0.016502
# T5             -0.013359
# S1             -0.062886
# S2             -0.075933
# S3             -0.016972
# C5p             0.068547
# LongSentences  -0.014935
# RealWords      -0.006787
# LongWords       0.028636
# PositiveWords  -0.050047
# NegativeWords  -0.097063
# UncertainWords  0.049952
# C2              0.044402
# C3p             0.033920
# Y1             -0.245474
# Y2              1.000000
#
# [25 rows x 25 columns]

# %%
#Testing to see which variables are highly correlated to our target variables (Y1 & Y2)
##Highly correlated being > 0.5
Target_1 = df.corr(method='spearman')['Y1'] > 0.5
Target_1
# Out:
# C1                False
# C3                False
# C4                False
# C5                False
# C6                False
# C7                False
# T1                False
# T2                False
# T3                False
# T4                False
# T5                False
# S1                False
# S2                False
# S3                False
# C5p               False
# LongSentences     False
# RealWords         False
# LongWords         False
# PositiveWords     False
# NegativeWords     False
# UncertainWords    False
# C2                False
# C3p               False
# Y1                 True
# Y2                False
# Name: Y1, dtype: bool

# %%
#Testing to see which variables are highly correlated to our target variables (Y1 & Y2)
##Highly correlated being > 0.5
Target_2 = df.corr(method='spearman')['Y2'] > 0.5
Target_2
# Out:
# C1                False
# C3                False
# C4                False
# C5                False
# C6                False
# C7                False
# T1                False
# T2                False
# T3                False
# T4                False
# T5                False
# S1                False
# S2                False
# S3                False
# C5p               False
# LongSentences     False
# RealWords         False
# LongWords         False
# PositiveWords     False
# NegativeWords     False
# UncertainWords    False
# C2                False
# C3p               False
# Y1                False
# Y2                 True
# Name: Y2, dtype: bool

# %% [markdown]
# **Correlation Heatmap**

# %%
#Created a figure and are able to adjust the size of the graph
plt.figure(figsize = (20,20))
#Created a heatmap using Seaborn to display the correlation based on 'Spearman' method
##Added the annotation so that the numbers appear in each box
display = sns.heatmap(df.corr(method = 'spearman'), annot=True, fmt='.2f', cmap='BuPu', linewidth=.75, cbar_kws={'shrink': .75})
#Created a title
plt.title('Correlation Heatmap')
# Out:
# Text(0.5, 1.0, 'Correlation Heatmap')

# %%
#Dropped columns that were very highly correlated to each other (i.e. correlation > 0.5). 
##Kept one of each of the highly correlated variable
df = df.drop(columns = ['T1', 'T2', 'T3', 'T4', 'S1', 'S2', 'C5'], axis=1)

# %%
#Recreated our heatmap to see how the chart is different 
#Created a figure and are able to adjust the size of the graph
plt.figure(figsize = (20,20))
#Created a heatmap using Seaborn to display the correlation based on 'Spearman' method
##Added the annotation so that the numbers appear in each box
display = sns.heatmap(df.corr(method = 'spearman'), annot=True, fmt='.2f', cmap='BuPu', linewidth=.75, cbar_kws={'shrink': .75})
#Created a title
plt.title('Correlation Heatmap')
# Out:
# Text(0.5, 1.0, 'Correlation Heatmap')

# %%
df.to_csv('../csv_files/p2correlation.csv')

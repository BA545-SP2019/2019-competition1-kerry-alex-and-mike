# %%
#Importing the packages that we need 
import pandas as pd
import numpy as np

# %%
#Loading in the csv file
df = pd.read_csv('../csv_files/p2final.csv', header=0, index_col=0)
df.head()
# Out:
#      I1                                  I2    I3  pIPO    pH    pL  \
# 0  AATI  ADVANCED ANALOGIC TECHNOLOGIES INC  3674  10.0   9.5   8.5
# 1  ABPI     ACCENTIA BIOPHARMACEUTICALS INC  2834   8.0  10.0   8.0
# 2  ACAD          ACADIA PHARMACEUTICALS INC  2834   7.0  14.0  12.0
# 3  ACHN       ACHILLION PHARMACEUTICALS INC  2834  11.5  16.0  14.0
# 4  ACLI     AMERICAN COMMERCIAL LINES INC.   4492  21.0  21.0  19.0
#
#        p1day  Pmid  Y1  Y2 ...         S3       C5p  LongSentences  RealWords  \
# 0  11.870000   9.0   0   1 ...   0.089906  0.056127       0.168742   0.385070
# 1   7.250000   9.0   1   0 ...   1.480823  2.434275       0.229402   0.151494
# 2   6.700000  13.0   1   0 ...  -1.864154 -0.231083       0.118150   0.395935
# 3  12.390000  15.0   1   1 ...  -0.482106 -0.274697      -1.243939   0.572453
# 4  56.599998  20.0   0   1 ...   0.554405 -0.020075      -0.574282  -0.085718
#
#    LongWords  PositiveWords  NegativeWords  UncertainWords   C2  C3p
# 0   0.310826      -0.146970       0.165628       -0.128062  1.0    0
# 1  -0.016168      -1.240880       0.781633       -0.147676  0.0    1
# 2   1.107680       2.767209      -0.974221        0.044649  1.0    1
# 3   1.094210       2.091907      -0.602916        0.697829  1.0    1
# 4  -0.357465      -0.364704       0.449384       -0.006421  1.0    0
#
# [5 rows x 34 columns]

# %%
#To fill the '-' values in 'I3' with 0
df['I3'].replace(to_replace='-', value=0, inplace=True)
df.head(10)
# Out:
#      I1                                  I2    I3  pIPO    pH    pL  \
# 0  AATI  ADVANCED ANALOGIC TECHNOLOGIES INC  3674  10.0   9.5   8.5
# 1  ABPI     ACCENTIA BIOPHARMACEUTICALS INC  2834   8.0  10.0   8.0
# 2  ACAD          ACADIA PHARMACEUTICALS INC  2834   7.0  14.0  12.0
# 3  ACHN       ACHILLION PHARMACEUTICALS INC  2834  11.5  16.0  14.0
# 4  ACLI     AMERICAN COMMERCIAL LINES INC.   4492  21.0  21.0  19.0
# 5  ACOM                  Ancestry.com Inc.   7379  13.5  14.5  12.5
# 6  ACOR             ACORDA THERAPEUTICS INC  2836   6.0  13.0  11.0
# 7  ACRX          ACELRX PHARMACEUTICALS INC  2834   5.0  14.0  12.0
# 8  ACTV                  ACTIVE NETWORK INC  7372  15.0  18.0  16.0
# 9   ACW                       ACCURIDE CORP  3714   9.0  19.0  17.0
#
#        p1day  Pmid  Y1  Y2 ...         S3       C5p  LongSentences  RealWords  \
# 0  11.870000   9.0   0   1 ...   0.089906  0.056127       0.168742   0.385070
# 1   7.250000   9.0   1   0 ...   1.480823  2.434275       0.229402   0.151494
# 2   6.700000  13.0   1   0 ...  -1.864154 -0.231083       0.118150   0.395935
# 3  12.390000  15.0   1   1 ...  -0.482106 -0.274697      -1.243939   0.572453
# 4  56.599998  20.0   0   1 ...   0.554405 -0.020075      -0.574282  -0.085718
# 5  14.200000  13.5   0   1 ...   0.762689  0.879085       0.206749  -2.820805
# 6   6.720000  12.0   1   1 ...   0.017303 -0.173474       1.923966  -0.155688
# 7   4.550000  13.0   1   0 ...  -0.231744 -0.922803       2.774601   0.083466
# 8  15.900000  17.0   1   1 ...   1.446154  0.517455      -1.234290   0.384780
# 9   0.000000  18.0   1   0 ...   0.230038 -0.434966      -1.599220  -0.106745
#
#    LongWords  PositiveWords  NegativeWords  UncertainWords   C2  C3p
# 0   0.310826      -0.146970       0.165628       -0.128062  1.0    0
# 1  -0.016168      -1.240880       0.781633       -0.147676  0.0    1
# 2   1.107680       2.767209      -0.974221        0.044649  1.0    1
# 3   1.094210       2.091907      -0.602916        0.697829  1.0    1
# 4  -0.357465      -0.364704       0.449384       -0.006421  1.0    0
# 5  -0.771004      -1.098306      -1.414049       -0.459496  1.0    0
# 6  -0.900494       0.044674      -0.776387       -1.072578  1.0    1
# 7  -7.097014      -0.132267       0.653746       -0.150614  0.0    1
# 8   1.121892      -0.760025      -0.128609        1.455401  1.0    1
# 9  -0.151382       1.774581       0.385979        1.540672  1.0    0
#
# [10 rows x 34 columns]

# %%
#Filling in ID #s that had originally had multiple values 
##Found the correct ID #s on the internet
df.iloc[118, df.columns.get_loc('I3')] = 5261
df.iloc[174, df.columns.get_loc('I3')] = 7812
df.iloc[181, df.columns.get_loc('I3')] = 191
df.iloc[187, df.columns.get_loc('I3')] = 5731
df.iloc[221, df.columns.get_loc('I3')] = 7389
df.iloc[246, df.columns.get_loc('I3')] = 7372
df.iloc[499, df.columns.get_loc('I3')] = 3663
df.iloc[620, df.columns.get_loc('I3')] = 5065

# %%
#Going to bin column 'I3'. Based on the Major Industries and then all 'others'

def assign_industry_bins(I3):
    if int(I3) >= 2000 and int(I3) <= 3999:  #Returning '1' if is in Manufacturing industry
        return(1)
    if int(I3) >= 7000 and int(I3) <= 8999:  #Returing '2' if is in Services industy
        return(2)
    else:                          #Returning '3' for all industries other than
        return(3)                  ##Manufacturing and Services

#Creating a Industry Bins column in the DataFrame
df['Industry_Bins'] = df['I3'].apply(assign_industry_bins)

# %%
df.head()
# Out:
#      I1                                  I2    I3  pIPO    pH    pL  \
# 0  AATI  ADVANCED ANALOGIC TECHNOLOGIES INC  3674  10.0   9.5   8.5
# 1  ABPI     ACCENTIA BIOPHARMACEUTICALS INC  2834   8.0  10.0   8.0
# 2  ACAD          ACADIA PHARMACEUTICALS INC  2834   7.0  14.0  12.0
# 3  ACHN       ACHILLION PHARMACEUTICALS INC  2834  11.5  16.0  14.0
# 4  ACLI     AMERICAN COMMERCIAL LINES INC.   4492  21.0  21.0  19.0
#
#        p1day  Pmid  Y1  Y2      ...             C5p  LongSentences  RealWords  \
# 0  11.870000   9.0   0   1      ...        0.056127       0.168742   0.385070
# 1   7.250000   9.0   1   0      ...        2.434275       0.229402   0.151494
# 2   6.700000  13.0   1   0      ...       -0.231083       0.118150   0.395935
# 3  12.390000  15.0   1   1      ...       -0.274697      -1.243939   0.572453
# 4  56.599998  20.0   0   1      ...       -0.020075      -0.574282  -0.085718
#
#    LongWords  PositiveWords  NegativeWords  UncertainWords   C2  C3p  \
# 0   0.310826      -0.146970       0.165628       -0.128062  1.0    0
# 1  -0.016168      -1.240880       0.781633       -0.147676  0.0    1
# 2   1.107680       2.767209      -0.974221        0.044649  1.0    1
# 3   1.094210       2.091907      -0.602916        0.697829  1.0    1
# 4  -0.357465      -0.364704       0.449384       -0.006421  1.0    0
#
#    Industry_Bins
# 0              1
# 1              1
# 2              1
# 3              1
# 4              3
#
# [5 rows x 35 columns]

# %%
df.to_csv('../csv_files/p2_binning.csv')

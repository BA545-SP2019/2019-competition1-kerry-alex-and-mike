# %% [markdown]
# **Import Data**

# %%
# import appropriate packages
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
# read the excel file
# had to install the xlrd package to read the file 
df = pd.read_csv("../csv_files/p2zscorex.csv", index_col=0)
df.head(10)
# Out:
#          C1        C4        C7       C5p       C6p       T4p       T3p  \
# 0  0.030756  0.669243 -0.477847  0.056127  1.282356  0.168742  0.174345
# 1  1.279824 -0.643726 -0.789310  2.434275 -0.759933  0.229402  0.099767
# 2 -0.431183  0.410546 -1.277684 -0.231083 -0.759933  0.118150  0.177807
# 3  0.907828  0.389135 -1.226569 -0.274697 -0.759933 -1.243939  0.233959
# 4 -0.603838 -1.310426  1.026514 -0.020075  1.027869 -0.574282  0.023718
# 5 -0.366577 -2.011735  0.251215  0.879085 -0.759933  0.206749 -0.877716
# 6  0.105821 -0.103473 -1.399794 -0.173474 -0.759933  1.923966  0.001225
# 7 -0.414811  1.026552 -0.117310 -0.922803 -0.759933  2.774601  0.077990
# 8 -0.273839 -1.137778  0.467093  0.517455 -0.759933 -1.234290  0.174253
# 9 -0.185627 -1.001893  0.849215 -0.434966 -0.759933 -1.599220  0.016961
#
#         T5p       S1p       S2p       S3p   C2  C3p
# 0  0.310826 -0.146970  0.165628 -0.128062  1.0    0
# 1 -0.016168 -1.240880  0.781633 -0.147676  0.0    1
# 2  1.107680  2.767209 -0.974221  0.044649  1.0    1
# 3  1.094210  2.091907 -0.602916  0.697829  1.0    1
# 4 -0.357465 -0.364704  0.449384 -0.006421  1.0    0
# 5 -0.771004 -1.098306 -1.414049 -0.459496  1.0    0
# 6 -0.900494  0.044674 -0.776387 -1.072578  1.0    1
# 7 -7.097014 -0.132267  0.653746 -0.150614  0.0    1
# 8  1.121892 -0.760025 -0.128609  1.455401  1.0    1
# 9 -0.151382  1.774581  0.385979  1.540672  1.0    0

# %%
# read in y variables csv 
dfy = pd.read_csv('../csv_files/y.csv', index_col=0)
dfy.head()
# Out:
#    pIPO    pH    pL      p1day  Pmid  Y1  Y2
# 0  10.0   9.5   8.5  11.870000   9.0   0   1
# 1   8.0  10.0   8.0   7.250000   9.0   1   0
# 2   7.0  14.0  12.0   6.700000  13.0   1   0
# 3  11.5  16.0  14.0  12.390000  15.0   1   1
# 4  21.0  21.0  19.0  56.599998  20.0   0   1

# %%
# filter our target variables Y1 nad Y2 
dfy = dfy.filter(['Y1', 'Y2'])
dfy.head()
# Out:
#    Y1  Y2
# 0   0   1
# 1   1   0
# 2   1   0
# 3   1   1
# 4   0   1

# %%
# concat df with dfy 
df = pd.concat([df, dfy], axis=1)
df.head()
# Out:
#          C1        C4        C7       C5p       C6p       T4p       T3p  \
# C5p  0.127415 -0.004915 -0.060438  0.070629  0.144462  0.016661 -0.057191
# C6p -0.083554 -0.075589 -0.115793 -0.032258  0.112178 -0.103095 -0.743601
# T4p -0.113664  0.054932 -0.042546 -0.105342  0.049188 -0.053634  0.074425
# T3p  0.455564  0.181572  0.075144  0.370785  0.013206  0.135436  0.113623
# T5p  1.000000  0.175733  0.154375  0.407211  0.122651  0.233787  0.126760
# S1p  0.175733  1.000000  0.131189  0.201370  0.064456 -0.060825  0.097424
# S2p  0.154375  0.131189  1.000000  0.137697  0.026141  0.055508  0.165504
# S3p  0.407211  0.201370  0.137697  1.000000  0.015669  0.113660  0.059701
# C2   0.122651  0.064456  0.026141  0.015669  1.000000 -0.007789 -0.071471
# C3p  0.233787 -0.060825  0.055508  0.113660 -0.007789  1.000000  0.114894
# Y1   0.126760  0.097424  0.165504  0.059701 -0.071471  0.114894  1.000000
# Y2   0.028636 -0.050047 -0.097063  0.049952  0.044402  0.033920 -0.245474
#
#            Y2
# C1  -0.009851
# C4   0.097813
# C7  -0.031607
# C5p  0.068547
# C6p  0.281459
# T4p -0.014935
# T3p -0.006787
# T5p  0.028636
# S1p -0.050047
# S2p -0.097063
# S3p  0.049952
# C2   0.044402
# C3p  0.033920
# Y1  -0.245474
# Y2   1.000000

# %%
#Testing to see which variables are highly correlated to our target variables (Y1 & Y2)
##Highly correlated being > 0.5
Target_1 = df.corr(method='spearman')['Y1'] > 0.5
Target_1
# Out:
# C1     False
# C4     False
# C7     False
# C5p    False
# C6p    False
# T4p    False
# T3p    False
# T5p    False
# S1p    False
# S2p    False
# S3p    False
# C2     False
# C3p    False
# Y1      True
# Y2     False
# Name: Y1, dtype: bool

# %%
#Testing to see which variables are highly correlated to our target variables (Y1 & Y2)
##Highly correlated being > 0.5
Target_2 = df.corr(method='spearman')['Y2'] > 0.5
Target_2
# Out:
# C1     False
# C4     False
# C7     False
# C5p    False
# C6p    False
# T4p    False
# T3p    False
# T5p    False
# S1p    False
# S2p    False
# S3p    False
# C2     False
# C3p    False
# Y1     False
# Y2      True
# Name: Y2, dtype: bool

# %% [markdown]
# **Correlation Heatmap**

# %%
#Created a figure and are able to adjust the size of the graph
plt.figure(figsize = (20,20))
#Created a heatmap using Seaborn to display the correlation based on 'Spearman' method
##Added the annotation so that the numbers appear in each box
display = sns.heatmap(df.corr(method = 'spearman'), annot=True, fmt='.2f', cmap='BuPu', linewidth=.75, cbar_kws={'shrink': .75})
#Created a title
plt.title('Correlation Heatmap')
# Out:
# Text(0.5, 1.0, 'Correlation Heatmap')

# %%
df.to_csv('../csv_files/p2correlation.csv')

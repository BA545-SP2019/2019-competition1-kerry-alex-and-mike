# %%
#Importing the packages that we need 
import pandas as pd
import numpy as np

# %%
#Loading in the csv file
dfx = pd.read_csv('csv_files/p1no_skew.csv', header=0, index_col=0)
dfx.head()
# Out:
#          C1        C3        C4        C5        C6        C7        T1  \
# 0  0.458312  1.000000  0.630418  0.637716  0.673869  0.207673  0.470752
# 1  1.000000  0.213889  0.384735  0.524141  0.290706  0.147494  0.917827
# 2  0.327366  0.284259  0.582011  0.378842  0.449107  0.078383  0.096100
# 3  0.814322  0.345370  0.578004  0.348897  0.423274  0.084319  0.272981
# 4  0.286445  0.526852  0.259982  0.543283  0.590068  0.729255  0.612813
#
#          T2        T3        T4 ...         S3       C5p  LongSentences  \
# 0  0.520721  0.522445  0.531139 ...   0.663736  0.570284       0.441786
# 1  0.895980  0.885128  0.903025 ...   0.906980  0.698942       0.444796
# 2  0.212300  0.216254  0.223310 ...   0.364079  0.555596       0.439275
# 3  0.336256  0.342301  0.310498 ...   0.572263  0.553374       0.371690
# 4  0.608032  0.595478  0.593416 ...   0.741423  0.566377       0.404918
#
#    RealWords  LongWords  PositiveWords  NegativeWords  UncertainWords   C2  \
# ...

# %%
#Loaded in the csv as a DataFrame
dfy = pd.read_csv('csv_files/y.csv', index_col=0)
dfy.head()
# Out:
#    pIPO    pH    pL      p1day  Pmid  Y1  Y2        C6p
# 0  10.0   9.5   8.5  11.870000   9.0   0   1  11.111111
# 1   8.0  10.0   8.0   7.250000   9.0   1   0   0.000000
# 2   7.0  14.0  12.0   6.700000  13.0   1   0   0.000000
# 3  11.5  16.0  14.0  12.390000  15.0   1   1   0.000000
# 4  21.0  21.0  19.0  56.599998  20.0   0   1   5.000000

# %%
#Loaded in the csv as a DataFrame
dfid = pd.read_csv('csv_files/id.csv', index_col=0)
dfid.head()
# Out:
#      I1                                  I2    I3
# 0  AATI  ADVANCED ANALOGIC TECHNOLOGIES INC  3674
# 1  ABPI     ACCENTIA BIOPHARMACEUTICALS INC  2834
# 2  ACAD          ACADIA PHARMACEUTICALS INC  2834
# 3  ACHN       ACHILLION PHARMACEUTICALS INC  2834
# 4  ACLI     AMERICAN COMMERCIAL LINES INC.   4492

# %%
#Concated the dfid and dfy DataFrames 
df = pd.concat([dfid, dfy], axis=1)
df.head()
# Out:
#      I1                                  I2    I3  pIPO    pH    pL  \
# 0  AATI  ADVANCED ANALOGIC TECHNOLOGIES INC  3674  10.0   9.5   8.5
# 1  ABPI     ACCENTIA BIOPHARMACEUTICALS INC  2834   8.0  10.0   8.0
# 2  ACAD          ACADIA PHARMACEUTICALS INC  2834   7.0  14.0  12.0
# 3  ACHN       ACHILLION PHARMACEUTICALS INC  2834  11.5  16.0  14.0
# 4  ACLI     AMERICAN COMMERCIAL LINES INC.   4492  21.0  21.0  19.0
#
#        p1day  Pmid  Y1  Y2        C6p
# 0  11.870000   9.0   0   1  11.111111
# 1   7.250000   9.0   1   0   0.000000
# 2   6.700000  13.0   1   0   0.000000
# 3  12.390000  15.0   1   1   0.000000
# 4  56.599998  20.0   0   1   5.000000

# %%
#Concated the df and dfx DataFrames
df = pd.concat([df, dfx], axis=1)
df.head()
# Out:
#      I1                                  I2    I3  pIPO    pH    pL  \
# 0  AATI  ADVANCED ANALOGIC TECHNOLOGIES INC  3674  10.0   9.5   8.5
# 1  ABPI     ACCENTIA BIOPHARMACEUTICALS INC  2834   8.0  10.0   8.0
# 2  ACAD          ACADIA PHARMACEUTICALS INC  2834   7.0  14.0  12.0
# 3  ACHN       ACHILLION PHARMACEUTICALS INC  2834  11.5  16.0  14.0
# 4  ACLI     AMERICAN COMMERCIAL LINES INC.   4492  21.0  21.0  19.0
#
#        p1day  Pmid  Y1  Y2 ...         S3       C5p  LongSentences  RealWords  \
# 0  11.870000   9.0   0   1 ...   0.663736  0.570284       0.441786   0.427704
# 1   7.250000   9.0   1   0 ...   0.906980  0.698942       0.444796   0.426904
# 2   6.700000  13.0   1   0 ...   0.364079  0.555596       0.439275   0.427741
# 3  12.390000  15.0   1   1 ...   0.572263  0.553374       0.371690   0.428343
# 4  56.599998  20.0   0   1 ...   0.741423  0.566377       0.404918   0.426088
#
#    LongWords  PositiveWords  NegativeWords  UncertainWords   C2  C3p
# ...

# %%
#To fill the '-' values in 'I3' with 0
df['I3'].replace(to_replace='-', value=0, inplace=True)
df.head(10)
# Out:
#      I1                                  I2    I3  pIPO    pH    pL  \
# 0  AATI  ADVANCED ANALOGIC TECHNOLOGIES INC  3674  10.0   9.5   8.5
# 1  ABPI     ACCENTIA BIOPHARMACEUTICALS INC  2834   8.0  10.0   8.0
# 2  ACAD          ACADIA PHARMACEUTICALS INC  2834   7.0  14.0  12.0
# 3  ACHN       ACHILLION PHARMACEUTICALS INC  2834  11.5  16.0  14.0
# 4  ACLI     AMERICAN COMMERCIAL LINES INC.   4492  21.0  21.0  19.0
# 5  ACOM                  Ancestry.com Inc.   7379  13.5  14.5  12.5
# 6  ACOR             ACORDA THERAPEUTICS INC  2836   6.0  13.0  11.0
# 7  ACRX          ACELRX PHARMACEUTICALS INC  2834   5.0  14.0  12.0
# 8  ACTV                  ACTIVE NETWORK INC  7372  15.0  18.0  16.0
# 9   ACW                       ACCURIDE CORP  3714   9.0  19.0  17.0
#
#        p1day  Pmid  Y1  Y2 ...         S3       C5p  LongSentences  RealWords  \
# 0  11.870000   9.0   0   1 ...   0.663736  0.570284       0.441786   0.427704
# ...

# %%
#Filling in ID #s that had originally had multiple values 
##Found the correct ID #s on the internet
df.iloc[118, df.columns.get_loc('I3')] = 5261
df.iloc[174, df.columns.get_loc('I3')] = 7812
df.iloc[181, df.columns.get_loc('I3')] = 191
df.iloc[187, df.columns.get_loc('I3')] = 5731
df.iloc[221, df.columns.get_loc('I3')] = 7389
df.iloc[246, df.columns.get_loc('I3')] = 7372
df.iloc[499, df.columns.get_loc('I3')] = 3663
df.iloc[620, df.columns.get_loc('I3')] = 5065

# %%
#Going to bin column 'I3'. Based on the Major Industries and then all 'others'

def assign_industry_bins(I3):
    if int(I3) >= 2000 and int(I3) <= 3999:  #Returning '1' if is in Manufacturing industry
        return(1)
    if int(I3) >= 7000 and int(I3) <= 8999:  #Returing '2' if is in Services industy
        return(2)
    else:                          #Returning '3' for all industries other than
        return(3)                  ##Manufacturing and Services

#Creating a Industry Bins column in the DataFrame
df['Industry_Bins'] = df['I3'].apply(assign_industry_bins)

# %%
#Printed out to make sure that the Binning worked 
df.head()
# Out:
#      I1                                  I2    I3  pIPO    pH    pL  \
# 0  AATI  ADVANCED ANALOGIC TECHNOLOGIES INC  3674  10.0   9.5   8.5
# 1  ABPI     ACCENTIA BIOPHARMACEUTICALS INC  2834   8.0  10.0   8.0
# 2  ACAD          ACADIA PHARMACEUTICALS INC  2834   7.0  14.0  12.0
# 3  ACHN       ACHILLION PHARMACEUTICALS INC  2834  11.5  16.0  14.0
# 4  ACLI     AMERICAN COMMERCIAL LINES INC.   4492  21.0  21.0  19.0
#
#        p1day  Pmid  Y1  Y2      ...             C5p  LongSentences  RealWords  \
# 0  11.870000   9.0   0   1      ...        0.570284       0.441786   0.427704
# 1   7.250000   9.0   1   0      ...        0.698942       0.444796   0.426904
# 2   6.700000  13.0   1   0      ...        0.555596       0.439275   0.427741
# 3  12.390000  15.0   1   1      ...        0.553374       0.371690   0.428343
# 4  56.599998  20.0   0   1      ...        0.566377       0.404918   0.426088
#
#    LongWords  PositiveWords  NegativeWords  UncertainWords   C2  C3p  \
# ...

# %%
#Saved to a csv
df.to_csv('csv_files/Binning_I3.csv')

# %% [markdown]
# **Binning**

# %%
#Importing the packages that we need 
import pandas as pd
import numpy as np

# %%
#Loading in the csv file
df = pd.read_csv('../csv_files/p1final.csv', header=0, index_col=0)
df.head()
# Out:
#      I1                                  I2    I3  pIPO    pH    pL  \
# 0  AATI  ADVANCED ANALOGIC TECHNOLOGIES INC  3674  10.0   9.5   8.5
# 1  ABPI     ACCENTIA BIOPHARMACEUTICALS INC  2834   8.0  10.0   8.0
# 2  ACAD          ACADIA PHARMACEUTICALS INC  2834   7.0  14.0  12.0
# 3  ACHN       ACHILLION PHARMACEUTICALS INC  2834  11.5  16.0  14.0
# 4  ACLI     AMERICAN COMMERCIAL LINES INC.   4492  21.0  21.0  19.0
#
#        p1day  Pmid  Y1  Y2 ...        C6p        C7       T3p       T4p  \
# 0  11.870000   9.0   0   1 ...   0.788811  0.278285  0.617569  0.534307
# 1   7.250000   9.0   1   0 ...   0.000000  0.197644  0.521720  0.545709
# 2   6.700000  13.0   1   0 ...   0.000000  0.105035  0.622040  0.524798
# 3  12.390000  15.0   1   1 ...   0.000000  0.112988  0.694834  0.268780
# 4  56.599998  20.0   0   1 ...   0.529150  0.977212  0.424900  0.394649
#
#         T5p       S1p       S2p       S3p   C2  C3p
# 0  0.567375  0.462525  0.532463  0.478776  1.0    0
# 1  0.489104  0.271483  0.667685  0.474754  0.0    1
# 2  0.773408  1.000000  0.324790  0.514761  1.0    1
# 3  0.769738  1.000000  0.386674  0.660248  1.0    1
# 4  0.411101  0.420367  0.592646  0.504014  1.0    0
#
# [5 rows x 23 columns]

# %%
#To fill the '-' values in 'I3' with 0
df['I3'].replace(to_replace='-', value=0, inplace=True)
df.head(10)
# Out:
#      I1                                  I2    I3  pIPO    pH    pL  \
# 0  AATI  ADVANCED ANALOGIC TECHNOLOGIES INC  3674  10.0   9.5   8.5
# 1  ABPI     ACCENTIA BIOPHARMACEUTICALS INC  2834   8.0  10.0   8.0
# 2  ACAD          ACADIA PHARMACEUTICALS INC  2834   7.0  14.0  12.0
# 3  ACHN       ACHILLION PHARMACEUTICALS INC  2834  11.5  16.0  14.0
# 4  ACLI     AMERICAN COMMERCIAL LINES INC.   4492  21.0  21.0  19.0
# 5  ACOM                  Ancestry.com Inc.   7379  13.5  14.5  12.5
# 6  ACOR             ACORDA THERAPEUTICS INC  2836   6.0  13.0  11.0
# 7  ACRX          ACELRX PHARMACEUTICALS INC  2834   5.0  14.0  12.0
# 8  ACTV                  ACTIVE NETWORK INC  7372  15.0  18.0  16.0
# 9   ACW                       ACCURIDE CORP  3714   9.0  19.0  17.0
#
#        p1day  Pmid  Y1  Y2 ...        C6p        C7       T3p       T4p  \
# 0  11.870000   9.0   0   1 ...   0.788811  0.278285  0.617569  0.534307
# 1   7.250000   9.0   1   0 ...   0.000000  0.197644  0.521720  0.545709
# 2   6.700000  13.0   1   0 ...   0.000000  0.105035  0.622040  0.524798
# 3  12.390000  15.0   1   1 ...   0.000000  0.112988  0.694834  0.268780
# 4  56.599998  20.0   0   1 ...   0.529150  0.977212  0.424900  0.394649
# 5  14.200000  13.5   0   1 ...   0.000000  0.546205  0.000000  0.541451
# 6   6.720000  12.0   1   1 ...   0.000000  0.087527  0.396441  0.864218
# 7   4.550000  13.0   1   0 ...   0.000000  0.395882  0.493900  1.000000
# 8  15.900000  17.0   1   1 ...   0.000000  0.649777  0.617450  0.270594
# 9   0.000000  18.0   1   0 ...   0.000000  0.863750  0.416342  0.202002
#
#         T5p       S1p       S2p       S3p   C2  C3p
# 0  0.567375  0.462525  0.532463  0.478776  1.0    0
# 1  0.489104  0.271483  0.667685  0.474754  0.0    1
# 2  0.773408  1.000000  0.324790  0.514761  1.0    1
# 3  0.769738  1.000000  0.386674  0.660248  1.0    1
# 4  0.411101  0.420367  0.592646  0.504014  1.0    0
# 5  0.321440  0.293531  0.258266  0.412542  1.0    0
# 6  0.294423  0.501419  0.357093  0.299493  1.0    1
# 7  0.000000  0.465449  0.638208  0.474152  0.0    1
# 8  0.777288  0.349176  0.473739  0.848390  1.0    1
# 9  0.457758  0.934464  0.578890  0.870921  1.0    0
#
# [10 rows x 23 columns]

# %%
#Filling in ID #s that had originally had multiple values 
##Found the correct ID #s on the internet
df.iloc[118, df.columns.get_loc('I3')] = 5261
df.iloc[174, df.columns.get_loc('I3')] = 7812
df.iloc[181, df.columns.get_loc('I3')] = 191
df.iloc[187, df.columns.get_loc('I3')] = 5731
df.iloc[221, df.columns.get_loc('I3')] = 7389
df.iloc[246, df.columns.get_loc('I3')] = 7372
df.iloc[499, df.columns.get_loc('I3')] = 3663
df.iloc[620, df.columns.get_loc('I3')] = 5065

# %%
#Going to bin column 'I3'. Based on the Major Industries and then all 'others'

def assign_industry_bins(I3):
    if int(I3) >= 2000 and int(I3) <= 3999:  #Returning '1' if is in Manufacturing industry
        return(1)
    if int(I3) >= 7000 and int(I3) <= 8999:  #Returing '2' if is in Services industy
        return(2)
    else:                          #Returning '3' for all industries other than
        return(3)                  ##Manufacturing and Services

#Creating a Industry Bins column in the DataFrame
df['Industry_Bins'] = df['I3'].apply(assign_industry_bins)

# %%
df.head()
# Out:
#      I1                                  I2    I3  pIPO    pH    pL  \
# 0  AATI  ADVANCED ANALOGIC TECHNOLOGIES INC  3674  10.0   9.5   8.5
# 1  ABPI     ACCENTIA BIOPHARMACEUTICALS INC  2834   8.0  10.0   8.0
# 2  ACAD          ACADIA PHARMACEUTICALS INC  2834   7.0  14.0  12.0
# 3  ACHN       ACHILLION PHARMACEUTICALS INC  2834  11.5  16.0  14.0
# 4  ACLI     AMERICAN COMMERCIAL LINES INC.   4492  21.0  21.0  19.0
#
#        p1day  Pmid  Y1  Y2      ...              C7       T3p       T4p  \
# 0  11.870000   9.0   0   1      ...        0.278285  0.617569  0.534307
# 1   7.250000   9.0   1   0      ...        0.197644  0.521720  0.545709
# 2   6.700000  13.0   1   0      ...        0.105035  0.622040  0.524798
# 3  12.390000  15.0   1   1      ...        0.112988  0.694834  0.268780
# 4  56.599998  20.0   0   1      ...        0.977212  0.424900  0.394649
#
#         T5p       S1p       S2p       S3p   C2  C3p  Industry_Bins
# 0  0.567375  0.462525  0.532463  0.478776  1.0    0              1
# 1  0.489104  0.271483  0.667685  0.474754  0.0    1              1
# 2  0.773408  1.000000  0.324790  0.514761  1.0    1              1
# 3  0.769738  1.000000  0.386674  0.660248  1.0    1              1
# 4  0.411101  0.420367  0.592646  0.504014  1.0    0              3
#
# [5 rows x 24 columns]

# %%
df.to_csv('../csv_files/p1_binning.csv')
